# %%
from openai import OpenAI
import os

api_key = os.environ.get('OPENAI_API_KEY')
print(api_key)

client = OpenAI()

completion = client.chat.completions.create(
  model="gpt-3.5-turbo",
  messages=[
    {"role": "system", "content": "You are a poetic assistant, skilled in explaining complex programming concepts with creative flair."},
    {"role": "user", "content": "Compose a poem that explains the concept of recursion in programming."}
  ]
)

print(completion.choices[0].message)
# Out:
# sk-proj-eYInqSsNBxPZBodenjZOT3BlbkFJ517HZuV1Y7e4G4BTpaOk
# ChatCompletionMessage(content='In the realm of code, there lies a loop so divine,\nWhere functions call themselves in a dance so fine.\nRecursion, they call it, a mystical art,\nA concept so elegant, straight from the heart.\n\nLike a mirror reflecting an image so true,\nRecursive functions return to renew.\nThey break down problems with each recursive call,\nSolving them smaller, conquering all.\n\nA base case, a condition, to set them free,\nTo stop the repetition, to let it just be.\nInfinite possibilities in a stack so tall,\nRecursion in programming, the grandest of all.\n\nSo embrace the beauty of this looping kind,\nLet your functions echo, expand your mind.\nFor in the world of code, where wonders unfold,\nRecursion reigns supreme, a tale to be told.', role='assistant', function_call=None, tool_calls=None, refusal=None)
